# %% [markdown]
# # Median House Price Prediction using Census Data of California

# %% [markdown]
# ### Importing Libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import shutil

# %%
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format

# %% [markdown]
# ### Reading Data

# %%
data_df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=',')

# %%
data_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
data_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# ### Splitting into train and test data

# %%
np.random.seed(1234)
train_records = np.random.rand(len(data_df)) < 0.8
train_df = data_df[train_records]
test_df = data_df[~train_records]
print(train_df.shape)
print(test_df.shape)
# Out:
# (13628, 9)
# (3372, 9)

# %% [markdown]
# ### Adding extra features

# %%
def add_new_features(df):
    df['num_rooms'] = df['total_rooms']/df['households']
    return(df)

# %% [markdown]
# ### Input Function

# %%
def make_input_function(df, num_epochs):
    return tf.estimator.inputs.pandas_input_fn(batch_size=128,
                                        num_epochs=num_epochs,
                                        x=add_new_features(df),
                                        y=df['median_house_value'],
                                        shuffle=True,
                                        num_threads=1,
                                        queue_capacity=1000)

# %% [markdown]
# ### Creating Feature Columns

# %%
def create_features():
    return [
        tf.feature_column.numeric_column('housing_median_age'),
        tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), boundaries = np.arange(32.0, 42, 1).tolist()),
        tf.feature_column.numeric_column('num_rooms'),
        tf.feature_column.numeric_column('median_income')
    ]

# %% [markdown]
# ### Creating Regressor

# %%
def train_and_evaluate(output_dir, num_train_steps):
    estimator = tf.estimator.LinearRegressor(feature_columns=create_features(), model_dir=output_dir)
    train_spec = tf.estimator.TrainSpec(input_fn = make_input_function(train_df, 8),
                                       max_steps = num_train_steps)
    eval_spec = tf.estimator.EvalSpec(input_fn = make_input_function(test_df, 1), 
                                    steps = None, 
                                    start_delay_secs = 1, # start evaluating after N seconds, 
                                    throttle_secs = 10) 
    tf.estimator.train_and_evaluate(estimator=estimator,train_spec=train_spec,eval_spec=eval_spec)

# %%
OUTDIR = '../Output'
shutil.rmtree(OUTDIR, ignore_errors = True)
train_and_evaluate(OUTDIR, 5000)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4d1d32bd90>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '../Output', '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# /home/avinash/.virtualenvs/keras_tf/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 6.14635e+12, step = 1
# INFO:tensorflow:global_step/sec: 402.912
# INFO:tensorflow:loss = 8.19713e+12, step = 101 (0.250 sec)
# INFO:tensorflow:global_step/sec: 429.173
# INFO:tensorflow:loss = 6.89695e+12, step = 201 (0.233 sec)
# INFO:tensorflow:global_step/sec: 451.522
# INFO:tensorflow:loss = 6.7968e+12, step = 301 (0.221 sec)
# INFO:tensorflow:global_step/sec: 466.276
# INFO:tensorflow:loss = 4.22282e+12, step = 401 (0.214 sec)
# INFO:tensorflow:global_step/sec: 465.307
# INFO:tensorflow:loss = 5.32459e+12, step = 501 (0.215 sec)
# INFO:tensorflow:global_step/sec: 460.45
# INFO:tensorflow:loss = 1.1303e+13, step = 601 (0.223 sec)
# INFO:tensorflow:global_step/sec: 464.46
# INFO:tensorflow:loss = 9.88629e+12, step = 701 (0.210 sec)
# INFO:tensorflow:global_step/sec: 469.799
# INFO:tensorflow:loss = 1.16774e+13, step = 801 (0.213 sec)
# INFO:tensorflow:Saving checkpoints for 852 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 6.85265e+12.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:22
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-852
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:22
# INFO:tensorflow:Saving dict for global step 852: average_loss = 5.47945e+10, global_step = 852, loss = 6.84322e+12
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-852
# INFO:tensorflow:Saving checkpoints for 853 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 2.75665e+12, step = 853
# INFO:tensorflow:global_step/sec: 420.255
# INFO:tensorflow:loss = 4.73307e+12, step = 953 (0.241 sec)
# INFO:tensorflow:global_step/sec: 463.863
# INFO:tensorflow:loss = 7.67974e+12, step = 1053 (0.215 sec)
# INFO:tensorflow:global_step/sec: 469.508
# INFO:tensorflow:loss = 1.19714e+13, step = 1153 (0.213 sec)
# INFO:tensorflow:global_step/sec: 483.437
# INFO:tensorflow:loss = 6.11823e+12, step = 1253 (0.209 sec)
# INFO:tensorflow:global_step/sec: 469.592
# INFO:tensorflow:loss = 6.55819e+12, step = 1353 (0.211 sec)
# INFO:tensorflow:global_step/sec: 466.435
# INFO:tensorflow:loss = 7.88667e+12, step = 1453 (0.217 sec)
# INFO:tensorflow:global_step/sec: 466.605
# INFO:tensorflow:loss = 8.58699e+12, step = 1553 (0.212 sec)
# INFO:tensorflow:global_step/sec: 463.266
# INFO:tensorflow:loss = 7.33012e+12, step = 1653 (0.216 sec)
# INFO:tensorflow:Saving checkpoints for 1704 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.51815e+12.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:25
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-1704
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:25
# INFO:tensorflow:Saving dict for global step 1704: average_loss = 5.47163e+10, global_step = 1704, loss = 6.83346e+12
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-1704
# INFO:tensorflow:Saving checkpoints for 1705 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 3.01969e+12, step = 1705
# INFO:tensorflow:global_step/sec: 400.607
# INFO:tensorflow:loss = 4.23474e+12, step = 1805 (0.252 sec)
# INFO:tensorflow:global_step/sec: 456.896
# INFO:tensorflow:loss = 5.57315e+12, step = 1905 (0.219 sec)
# INFO:tensorflow:global_step/sec: 470.108
# INFO:tensorflow:loss = 1.07914e+13, step = 2005 (0.213 sec)
# INFO:tensorflow:global_step/sec: 465.864
# INFO:tensorflow:loss = 1.35578e+13, step = 2105 (0.215 sec)
# INFO:tensorflow:global_step/sec: 457.189
# INFO:tensorflow:loss = 5.30105e+12, step = 2205 (0.218 sec)
# INFO:tensorflow:global_step/sec: 471.471
# INFO:tensorflow:loss = 7.20944e+12, step = 2305 (0.212 sec)
# INFO:tensorflow:global_step/sec: 467.002
# INFO:tensorflow:loss = 7.7308e+12, step = 2405 (0.214 sec)
# INFO:tensorflow:global_step/sec: 453.496
# INFO:tensorflow:loss = 7.03126e+12, step = 2505 (0.221 sec)
# INFO:tensorflow:Saving checkpoints for 2556 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.33157e+12.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:28
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-2556
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:28
# INFO:tensorflow:Saving dict for global step 2556: average_loss = 5.46565e+10, global_step = 2556, loss = 6.82599e+12
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-2556
# INFO:tensorflow:Saving checkpoints for 2557 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 3.69618e+12, step = 2557
# INFO:tensorflow:global_step/sec: 394.342
# INFO:tensorflow:loss = 7.59457e+12, step = 2657 (0.256 sec)
# INFO:tensorflow:global_step/sec: 463.994
# INFO:tensorflow:loss = 8.21972e+12, step = 2757 (0.215 sec)
# INFO:tensorflow:global_step/sec: 457.172
# INFO:tensorflow:loss = 1.18913e+13, step = 2857 (0.219 sec)
# INFO:tensorflow:global_step/sec: 436.435
# INFO:tensorflow:loss = 8.09822e+12, step = 2957 (0.229 sec)
# INFO:tensorflow:global_step/sec: 460.105
# INFO:tensorflow:loss = 3.40587e+12, step = 3057 (0.217 sec)
# INFO:tensorflow:global_step/sec: 463.209
# INFO:tensorflow:loss = 3.2424e+12, step = 3157 (0.216 sec)
# INFO:tensorflow:global_step/sec: 460.238
# INFO:tensorflow:loss = 3.84908e+12, step = 3257 (0.218 sec)
# INFO:tensorflow:global_step/sec: 464.751
# INFO:tensorflow:loss = 7.23779e+12, step = 3357 (0.215 sec)
# INFO:tensorflow:Saving checkpoints for 3408 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.53289e+12.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:31
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-3408
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:31
# INFO:tensorflow:Saving dict for global step 3408: average_loss = 5.46062e+10, global_step = 3408, loss = 6.81971e+12
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-3408
# INFO:tensorflow:Saving checkpoints for 3409 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 6.02698e+12, step = 3409
# INFO:tensorflow:global_step/sec: 391.102
# INFO:tensorflow:loss = 1.20836e+13, step = 3509 (0.259 sec)
# INFO:tensorflow:global_step/sec: 451.235
# INFO:tensorflow:loss = 7.39006e+12, step = 3609 (0.221 sec)
# INFO:tensorflow:global_step/sec: 475.78
# INFO:tensorflow:loss = 6.00174e+12, step = 3709 (0.210 sec)
# INFO:tensorflow:global_step/sec: 462.276
# INFO:tensorflow:loss = 7.22698e+12, step = 3809 (0.217 sec)
# INFO:tensorflow:global_step/sec: 459.582
# INFO:tensorflow:loss = 7.66151e+12, step = 3909 (0.218 sec)
# INFO:tensorflow:global_step/sec: 468.055
# INFO:tensorflow:loss = 6.87001e+12, step = 4009 (0.216 sec)
# INFO:tensorflow:global_step/sec: 465.133
# INFO:tensorflow:loss = 7.2375e+12, step = 4109 (0.212 sec)
# INFO:tensorflow:global_step/sec: 459.025
# INFO:tensorflow:loss = 4.17856e+12, step = 4209 (0.219 sec)
# INFO:tensorflow:Saving checkpoints for 4260 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.16101e+13.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:34
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-4260
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:34
# INFO:tensorflow:Saving dict for global step 4260: average_loss = 5.4562e+10, global_step = 4260, loss = 6.81419e+12
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-4260
# INFO:tensorflow:Saving checkpoints for 4261 into ../Output/model.ckpt.
# INFO:tensorflow:loss = 3.0429e+12, step = 4261
# INFO:tensorflow:global_step/sec: 415.315
# INFO:tensorflow:loss = 6.13624e+12, step = 4361 (0.245 sec)
# INFO:tensorflow:global_step/sec: 464.125
# INFO:tensorflow:loss = 1.35852e+13, step = 4461 (0.213 sec)
# INFO:tensorflow:global_step/sec: 455.737
# INFO:tensorflow:loss = 1.1222e+13, step = 4561 (0.220 sec)
# INFO:tensorflow:global_step/sec: 447.626
# INFO:tensorflow:loss = 5.35903e+12, step = 4661 (0.223 sec)
# INFO:tensorflow:global_step/sec: 458.383
# INFO:tensorflow:loss = 6.14789e+12, step = 4761 (0.218 sec)
# INFO:tensorflow:global_step/sec: 458.24
# INFO:tensorflow:loss = 7.37429e+12, step = 4861 (0.220 sec)
# INFO:tensorflow:global_step/sec: 449.598
# INFO:tensorflow:loss = 7.98422e+12, step = 4961 (0.221 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ../Output/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.61929e+12.
# INFO:tensorflow:Starting evaluation at 2018-06-24-15:13:37
# INFO:tensorflow:Restoring parameters from ../Output/model.ckpt-5000
# INFO:tensorflow:Finished evaluation at 2018-06-24-15:13:37
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 5.45271e+10, global_step = 5000, loss = 6.80983e+12
